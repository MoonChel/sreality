# %%
import altair as alt
import pandas as pd

data = pd.read_csv("./result.csv")

# %%
alt.Chart(data).mark_point().encode(x="locality", y="price")
# Out:
# alt.Chart(...)

# %%
alt.Chart(data).mark_point().encode(x="et_type", y="price")
# Out:
# alt.Chart(...)

# %%
data_3_1_3_kk = data[data["et_type"].isin(["3+1", "3+kk"])]

alt.Chart(data_3_1_3_kk).mark_point().encode(x="locality", y="price")
# Out:
# alt.Chart(...)

# %%
data_2_1_2_kk = data[data["et_type"].isin(["2+1", "2+kk"])]

alt.Chart(data_2_1_2_kk).mark_point().encode(x="locality", y="price")
# Out:
# alt.Chart(...)

# %%
# sorting by max count of estates
# display and sort by size and price
# display and sort by average price and locality

# questions
# are 2+1 are more expensive than 3+1?
#
